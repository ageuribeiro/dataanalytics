# %%
import pandas as pd

# %%
copacabana = pd.read_csv('copacabana.csv', delimiter=';')

# %%
copacabana
# Out:
#       Posicao  Quartos  Vagas  ...  VAL_UNIT            X            Y
# 0           1      3.0   0.01  ...      4379  685365.0700  7457802.680
# 1           0      2.0   0.01  ...      6479  685941.5500  7459001.320
# 2           0      2.0   0.01  ...     12414  685627.3900  7459080.520
# 3           0      2.0   0.01  ...     11250  685438.2001  7458268.280
# 4           0      2.0   1.00  ...     13382  685764.3840  7458954.513
# ...       ...      ...    ...  ...       ...          ...          ...
# 1670        1      2.0   2.00  ...      4210  686269.4600  7459312.080
# 1671        1      2.0   2.00  ...      4232  685346.9700  7459162.110
# 1672        1      2.0   2.00  ...      6316  685346.9700  7459162.110
# 1673        1      2.0   2.00  ...      6785  685346.9700  7459162.110
# 1674        1      2.0   2.00  ...      6771  685346.9700  7459162.110
#
# [1675 rows x 17 columns]

# %%
copacabana.head()
# Out:
#    Posicao  Quartos  Vagas  ...  VAL_UNIT            X            Y
# 0        1      3.0   0.01  ...      4379  685365.0700  7457802.680
# 1        0      2.0   0.01  ...      6479  685941.5500  7459001.320
# 2        0      2.0   0.01  ...     12414  685627.3900  7459080.520
# 3        0      2.0   0.01  ...     11250  685438.2001  7458268.280
# 4        0      2.0   1.00  ...     13382  685764.3840  7458954.513
#
# [5 rows x 17 columns]

# %%
populacao_pe = pd.read_excel('total_populacao_pernambuco.xls')

# %%
populacao_pe
# Out:
#                         Código do município  ... Total da população 2010
# 0                                   2600054  ...                 94428.0
# 1                                   2600104  ...                 35091.0
# 2                                   2600203  ...                 17588.0
# 3                                   2600302  ...                 22680.0
# 4                                   2600401  ...                 33046.0
# ..                                      ...  ...                     ...
# 182                                 2616308  ...                 30731.0
# 183                                 2616407  ...                130540.0
# 184                                 2616506  ...                 14092.0
# 185                                   Total  ...               8796032.0
# 186  Fonte: IBGE, Resultados do Censo 2010.  ...                     NaN
#
# [187 rows x 8 columns]

# %%
populacao_pe.head()
# Out:
#   Código do município  ... Total da população 2010
# 0             2600054  ...                 94428.0
# 1             2600104  ...                 35091.0
# 2             2600203  ...                 17588.0
# 3             2600302  ...                 22680.0
# 4             2600401  ...                 33046.0
#
# [5 rows x 8 columns]
