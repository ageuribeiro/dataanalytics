# %%
#implementação knn
amostras = []

with open('haberman.data','r') as f:
  for line in f.readlines():
    atrib = line.replace('\n', '').split(',')
    amostras.append([int(atrib[0]), int(atrib[1]),int(atrib[2]),int(atrib[3])])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-bd5ae1c99055> in <module>()
#       2 amostras = []
#       3
# ----> 4 with open('haberman.data','r') as f:
#       5   for line in f.readlines():
#       6     atrib = line.replace('\n', '').split(',')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'haberman.data'

# %%
amostras
